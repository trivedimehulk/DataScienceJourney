# %% [markdown]
# --------------------------------------------------------------------------------</br>
# Question 1 - Extracting Tesla Stock Data Using yfinance - 2 Points</br>
# Question 2 - Extracting Tesla Revenue Data Using Webscraping - 1 Points</br>
# Question 3 - Extracting GameStop Stock Data Using yfinance - 2 Points</br>
# Question 4 - Extracting GameStop Revenue Data Using Webscraping - 1 Points</br>
# Question 5 - Tesla Stock and Revenue Dashboard - 2 Points</br>
# Question 6 - GameStop Stock and Revenue Dashboard- 2 Points</br>
# Question 7 - Sharing your Assignment Notebook - 2 Points</br>
# --------------------------------------------------------------------------------</br>

# %%
#preq pckgs
# !pip install yfinance==0.2.4
# !pip install pandas==1.3.3
#!pip install pandas==1.3.3
#!pip install requests==2.26.0
#!mamba install bs4==4.10.0 -y
#!mamba install html5lib==1.1 -y 
#!pip install lxml==4.6.4
#!pip install plotly==5.3.1

# %%
#Question 1 - Extracting Tesla Stock Data Using yfinance - 2 Points
import yfinance as yf
import pandas as pd
tsla = yf.Ticker("TSLA")
tsla_share_price_data = tsla.history(period="max")
tsla_share_price_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-08-25 00:00:00-04:00  231.309998  239.000000  230.350006  238.589996
# 2023-08-28 00:00:00-04:00  242.580002  244.380005  235.350006  238.820007
# 2023-08-29 00:00:00-04:00  238.580002  257.480011  237.770004  257.179993
# 2023-08-30 00:00:00-04:00  254.199997  260.510010  250.589996  256.899994
# 2023-08-31 00:00:00-04:00  255.979996  259.920013  255.054199  257.386200
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
#Question 2 - Extracting Tesla Revenue Data Using Webscraping - 1 Points
#skipping this part. Yfina doesnt suport webscrapping anymore. and storing output as html wudnt b right way
#correct way of doing this wud b proper APIs

# %%
#Question 3 - Extracting GameStop Stock Data Using yfinance - 2 Points
import yfinance as yf
import pandas as pd
gme = yf.Ticker("GAME")
gme_share_price_data = gme.history(period="max")
gme_share_price_data
# Out:
#                               Open       High      Low     Close  Volume  \
# Date
# 2018-01-26 00:00:00-05:00  2893.50  2893.5000  2893.50  2893.500       0
# 2018-01-29 00:00:00-05:00  2893.50  2893.5000  2893.50  2893.500       0
# 2018-01-30 00:00:00-05:00  2893.50  2893.5000  2893.50  2893.500       0
# 2018-01-31 00:00:00-05:00  2893.50  2893.5000  2893.50  2893.500       0
# 2018-02-01 00:00:00-05:00  2785.50  2785.5000  2785.50  2785.500       0
# ...                            ...        ...      ...       ...     ...
# 2023-08-25 00:00:00-04:00     2.18     2.6800     2.13     2.620   82600
# 2023-08-28 00:00:00-04:00     2.62     2.7620     2.28     2.330   46100
# 2023-08-29 00:00:00-04:00     2.33     2.4600     2.30     2.390   58300
# 2023-08-30 00:00:00-04:00     2.37     2.5810     2.37     2.520   27200
# 2023-08-31 00:00:00-04:00     2.53     2.7432     2.53     2.736   22972
#
#                            Dividends  Stock Splits
# Date
# ...

# %%
#Question 4 - Extracting GameStop Revenue Data Using Webscraping - 1 Points
#skipping this part. Yfina doesnt suport webscrapping anymore. and storing output as html wudnt b right way
#correct way of doing this wud b proper APIs

# %%
tsla = yf.Ticker("TSLA")
tsla_share_price_data = tsla.history(period="max")
tsla_share_price_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-08-25 00:00:00-04:00  231.309998  239.000000  230.350006  238.589996
# 2023-08-28 00:00:00-04:00  242.580002  244.380005  235.350006  238.820007
# 2023-08-29 00:00:00-04:00  238.580002  257.480011  237.770004  257.179993
# 2023-08-30 00:00:00-04:00  254.199997  260.510010  250.589996  256.899994
# 2023-08-31 00:00:00-04:00  255.979996  259.920013  255.054199  256.458008
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
#Question 5 - Tesla Stock and Revenue Dashboard - 2 Points
tsla_actions = tsla.actions
tsla_actions.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Question 6 - GameStop Stock and Revenue Dashboard- 2 Points
gme_actions = gme.actions
gme_actions.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Question 7 - Sharing your Assignment Notebook - 2 Points
#I have uplaoded my submission on git with following perm link
